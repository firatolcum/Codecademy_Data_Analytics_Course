# %% [markdown]
# ## Visualizing Catogorical Data
# Visualizing categorical data mainly involves the use of pie charts and bar charts.In this lesson, we will explore both of these graphs including:
# - use cases
# - pros and cons
# - modifying them for best communication

# %% [markdown]
# ### Plotting Bar Charts Using Seaborn
# Let’s practice plotting our own bar chart. In plot.py, there is a csv file loaded called games.csv. This dataset contains information about various chess games, including:
# - Number of turns the game took
# - Ending result (checkmate/draw/resign)
# - Who won (player with white pieces or black pieces)
# - Other variables
#
# Plot the counts of each value in `victory_status` using the `.countplot()` method. Be sure to show your plot after using the method.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("games.csv")
df.head(3)
# Out:
#          id  rated    created_at  last_move_at  turns victory_status winner  \
# 0  TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime  white
# 1  l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign  black
# 2  mIICvQHh   True  1.504130e+12  1.504130e+12     61           mate  white
#
#   increment_code  white_id  white_rating   black_id  black_rating  \
# 0           15+2  bourgris          1500       a-00          1191
# 1           5+10      a-00          1322  skinnerua          1261
# 2           5+10    ischia          1496       a-00          1500
#
#                                                moves opening_eco  \
# 0  d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5...         D10
# 1  d4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6...         B00
# 2  e4 e5 d3 d6 Be3 c6 Be2 b5 Nd2 a5 a4 c5 axb5 Nc...         C20
#
#                              opening_name  opening_ply
# 0        Slav Defense: Exchange Variation            5
# ...

# %% [markdown]
# ### Bar Chart Ordering
#
# Seaborn is a library that makes it easy to create bar charts with the `.countplot()` method.
# #### 1. Nominal Data

# %%
sns.countplot(df["victory_status"]);

# %%
df["victory_status"].value_counts(ascending=True).index
# Out:
# Index(['draw', 'outoftime', 'mate', 'resign'], dtype='object')

# %%
sns.countplot(df["victory_status"], order = df["victory_status"].value_counts(ascending=True).index);

# %% [markdown]
# #### 2. Ordinal Data

# %%
df = pd.read_csv("school_data.csv")
df.head()
# Out:
#    School ID                                Name of School  \
# 0     400048                      LEARN Charter ES - Excel
# 1     609871  Barbara Vick Early Childhood & Family Center
# 2     610083              Daniel C Beard Elementary School
# 3     610066    James E McDade Elementary Classical School
# 4     400092             Chicago Intl Charter - Lloyd Bond
#
#          Street Address     City State  ZIP Code    Phone Number  \
# 0  2401 W Congress Pkwy  Chicago    IL     60612  (312) 243-7001
# 1       2554 W 113th St  Chicago    IL     60655  (773) 535-2671
# 2      6445 W Strong St  Chicago    IL     60656  (773) 534-1228
# 3    8801 S Indiana Ave  Chicago    IL     60619  (773) 535-3669
# 4   13300 S Langley Ave  Chicago    IL     60827  (773) 468-1300
#
#                                  Website  Blue Ribbon Award  \
# 0            http://www.learncharter.org                NaN
# 1   http://www.barbaravick.cps.k12.il.us                NaN
# ...

# %%
df["Quality of Facilities"].value_counts()
# Out:
# NEUTRAL            154
# NOT ENOUGH DATA    125
# STRONG              93
# WEAK                56
# VERY STRONG         38
# VERY WEAK           12
# Name: Quality of Facilities, dtype: int64

# %%
sns.countplot(df["Quality of Facilities"], order = ["NOT ENOUGH DATA","VERY WEAK", "WEAK", "NEUTRAL", "STRONG", "VERY STRONG"])
plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# ### Pie Charts
# Before we dive into pie chart use cases and how to plot them, we want to address the fact that pie charts are the most issue-ridden graphing visual.
#
# The seaborn library does not currently have any pie chart libraries.

# %%
water_usage = pd.read_csv("water_usage.csv")
water_usage
# Out:
#   water_source  prop
# 0  Shower/Bath  0.19
# 1      Faucets  0.23
# 2       Washer  0.32
# 3       Toilet  0.19
# 4        Other  0.07

# %%
plt.pie(water_usage["prop"], labels=  water_usage["water_source"])

plt.axis("equal")
plt.title("Distribution of House Water Usage")
plt.show()

# %%
pie_data = pd.read_csv("pie_data.csv")
pie_data
# Out:
#   labels  values
# 0      A      18
# 1      B      23
# 2      C      22
# 3      D      18
# 4      E      19

# %%
plt.subplot(1,2,1)
plt.pie(pie_data["values"], labels = pie_data["labels"])
plt.axis("equal")
plt.title("Tough to Compare")

plt.subplot(1,2,2)
sns.barplot(data = pie_data, x = "labels", y = "values")
plt.title("Easy to Compare")

plt.show()
