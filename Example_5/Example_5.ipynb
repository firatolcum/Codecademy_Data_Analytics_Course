# %%
"""
1. Return the first 10 rows of the auto dataframe.
"""
import pandas as pd
autos = pd.read_csv()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Samsung\Desktop\Codecademy-Data-Analysis\Example 5\autos.ipynb Cell 1' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Samsung/Desktop/Codecademy-Data-Analysis/Example%205/autos.ipynb#ch0000000?line=0'>1</a> """
#       <a href='vscode-notebook-cell:/c%3A/Users/Samsung/Desktop/Codecademy-Data-Analysis/Example%205/autos.ipynb#ch0000000?line=1'>2</a> 1. Return the first 10 rows of the auto dataframe.
#       <a href='vscode-notebook-cell:/c%3A/Users/Samsung/Desktop/Codecademy-Data-Analysis/Example%205/autos.ipynb#ch0000000?line=2'>3</a> """
#       <a href='vscode-notebook-cell:/c%3A/Users/Samsung/Desktop/Codecademy-Data-Analysis/Example%205/autos.ipynb#ch0000000?line=3'>4</a> import pandas as pd
# ...
